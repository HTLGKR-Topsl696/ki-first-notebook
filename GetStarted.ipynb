# %% [markdown]
# # Topsl's First Notebook

# %%
x = 4

# %% [markdown]
# ## Variablen Gültikkeitsbereich
# Die Variablen sind auch in nachfolgenden Zellen noch verfügbar.

# %%
x
# Out:
# 4

# %% [markdown]
# ## Pip packages installieren
# Befehle können mit !ausgeführt werden.

# %%
# !pip install pyautogui
# Out:
# Uninstalling PyAutoGUI-0.9.52:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/PyAutoGUI-0.9.52.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/pyautogui/*
# Proceed (y/n)? y
#   Successfully uninstalled PyAutoGUI-0.9.52
